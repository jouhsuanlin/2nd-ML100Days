# %%
作業1：

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要
我選的是"Kaggle_Dataset_Heart Disease UCI"，可以透過資料蒐集和分析，能較精確的判斷心臟病相關特徵，判斷心臟病的發生可能性，並實現提早發現提早治療的優勢。

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
Creators: 
-Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D. 
-University Hospital, Zurich, Switzerland: William Steinbrunn, M.D. 
-University Hospital, Basel, Switzerland: Matthias Pfisterer, M.D. 
-V.A. Medical Center, Long Beach and Cleveland Clinic Foundation: Robert Detrano, M.D., Ph.D.
Donor: David W. Aha (aha '@' ics.uci.edu) (714) 856-8779

3. 蒐集而來的資料型態為何
csv檔

4. 這組資料想解決的問題如何評估
用精確的儀器對可能罹患心臟病的患者做檢測，就能判斷患者是不是真的有罹患心臟病，細節情況怎麼樣等，且蒐集到更多的數值，也能提高模型未來的準確度。

# %%
作業2：

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
知道車隊的經營客群有哪些特徵、其搭車的目的等，瞄準顧客的需求的話就能提升業績。

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
會員資料庫的建立，發送些會員問卷，定期做些問卷調查，追蹤顧客狀態。

3. 蒐集而來的資料型態為何
用google問卷表單，會是excel檔或csv檔

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
看看做的活動反應狀況如何，業績有提升就達標了。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 204.486
# The Mean absolute error is 11.238
